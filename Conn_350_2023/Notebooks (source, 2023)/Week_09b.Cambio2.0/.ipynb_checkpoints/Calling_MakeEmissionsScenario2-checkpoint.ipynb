# %%
import numpy as np
import matplotlib.pyplot as plt
import Conn350Lib as CL

# %%
# %matplotlib notebook

# %%
# Parameters of the emissions schedule
SF_t_start = 1750
SF_t_stop = 2300
SF_nsteps = 1000
SF_k = 0.025
SF_t_trans = 2050
SF_delta_t_trans = 20
SF_t_peak = 2040
SF_t_0 = 2020
SF_eps_0 = 11.3

# Calling the emissions scenario maker
time, eps = CL.MakeEmissionsScenario2(\
    SF_t_start,SF_t_stop,SF_nsteps,SF_k,SF_eps_0,SF_t_0,SF_t_peak,SF_delta_t_trans)
plt.figure()
plt.plot(time,eps)
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="639.65">
