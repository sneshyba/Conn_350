# %%
import numpy as np
from numpy import genfromtxt
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib notebook
import sys; sys.path.append('/home'); import Conn350Lib as CL

# %%
data = np.loadtxt ('EnROADS_with_Carbon_Price.txt') # This file has spaces as delimiters
# data =genfromtxt('En-Roads Baselinecsv.csv', delimiter=",")

# Getting the time array
time=data[:,0]

# Converting GtCO2/year to GtC/year (baseline and current scenario)
baseline = data[:,1]*0.27
current_sec = data[:,2]*0.27

# Plotting
plt.figure()
plt.plot(time,baseline, label="baseline")
plt.plot(time,current_sec, label = 'Current Scenario')
plt.xlabel('year')
plt.ylabel('emissions (gt C/year)')
plt.title('CO2 equivalent emissions by year')
plt.legend()
plt.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="639.6666666666666">

# %%
# This makes a hybrid emissions scenario file from the array "current_sec"
t_start = 1750
t_stop = 2100
filename = 'eps_hybrid.hdf5'
CL.MakeHybridEmissionScenario(t_start,t_stop,time,current_sec,filename,reportflag=False,plotflag=True)
# Out:
# 11.026800000000001
# 2000.0
# peak 11.043091507295472 716
# 715 2000.5005005005005
# 1000

# %%
# This is how you would read it in Cambio3.0
time_hybrid, eps_hybrid = CL.GetMyScenario(filename,reportflag=True,plotflag=True)
# Out:
# Here's the scenario summary:
# {'dataframe':             time  emissions
#  0    1750.000000   0.024951
#  1    1750.350350   0.025171
#  2    1750.700701   0.025392
#  3    1751.051051   0.025615
#  4    1751.401401   0.025841
#  ..           ...        ...
#  995  2098.598599   8.589814
#  996  2098.948949   8.582246
#  997  2099.299299   8.575081
#  998  2099.649650   8.568459
#  999  2100.000000   8.561838
#
#  [1000 rows x 2 columns]}
# <img src="data:image/png;base64,..." width="639.6666666666666">
